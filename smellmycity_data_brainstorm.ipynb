# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/caro28/ds5110_project/main/smell_reports.csv'

df = pd.read_csv(url)

print(df.shape)
df.head()
# Out:
# (2574, 9)
#    epoch time  ... additional comments
# 0  1558531873  ...                 NaN
# 1  1558691615  ...                 NaN
# 2  1559178135  ...                 NaN
# 3  1559341934  ...                 NaN
# 4  1559387558  ...                 NaN
#
# [5 rows x 9 columns]

# %%
df.fillna(value={'smell description':'None'}, inplace=True)
df.head()
# Out:
#    epoch time  ... additional comments
# 0  1558531873  ...                 NaN
# 1  1558691615  ...                 NaN
# 2  1559178135  ...                 NaN
# 3  1559341934  ...                 NaN
# 4  1559387558  ...                 NaN
#
# [5 rows x 9 columns]

# %%
smell_txt = df['smell description']
smell_txt[1]
# Out:
# 'None'

# %%
'''
https://stackoverflow.com/questions/51860716/how-save-a-array-to-text-file-in-python/51860833
'''
# save tweet_text in txt file (required input for wordcloud)
with open("output.txt", "w") as txt_file:
  for item in smell_txt:
    if item != "None":
      txt_file.write("".join(item) + "\n")

# %%
'''
Word cloud for python by Andreas Mueller: http://amueller.github.io/word_cloud/
Example code used below: https://github.com/amueller/word_cloud/blob/master/examples/simple.py
'''
import os

from os import path
from wordcloud import WordCloud

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
text = open(path.join(d, '/content/output.txt')).read()

wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
